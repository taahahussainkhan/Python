# %% [markdown]
# **Introduction**

# %%
import pandas as pd

# %% [markdown]
# **DataFrame**

# %%
df = pd.read_csv("/content/drive/MyDrive/Black_friday_sales1.csv", header = 0)

# %%
df.head(15)
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000004  P00128942      M  46-50           7             B
# 1   1000009  P00113442      M  26-35          17             C
# 2   1000010  P00288442      F  36-45           1             B
# 3   1000010  P00145342      F  36-45           1             B
# 4   1000011  P00053842      F  26-35           1             C
# 5   1000013  P00350442      M  46-50           1             C
# 6   1000013  P00155442      M  46-50           1             C
# 7   1000013   P0094542      M  46-50           1             C
# 8   1000015  P00161842      M  26-35           7             A
# 9   1000022  P00067942      M  18-25          15             A
# 10  1000026  P00046742      M  26-35           7             B
# 11  1000026  P00040042      M  26-35           7             B
# 12  1000026  P00196542      M  26-35           7             B
# 13  1000026  P00004542      M  26-35           7             B
# 14  1000028  P00159542      F  26-35           1             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               1                   1
# 1                           0               0                   3
# 2                          4+               1                   5
# 3                          4+               1                   4
# 4                           1               0                   4
# 5                           3               1                   2
# 6                           3               1                   1
# 7                           3               1                   2
# 8                           1               0                  10
# 9                          4+               0                   5
# 10                          2               1                   1
# 11                          2               1                   5
# 12                          2               1                   5
# 13                          2               1                   5
# 14                          2               1                  10
#
#     Product_Category_2  Product_Category_3
# 0                 11.0                 NaN
# 1                  5.0                 NaN
# 2                 14.0                 NaN
# 3                  9.0                 NaN
# 4                  5.0                12.0
# 5                  3.0                15.0
# 6                 11.0                15.0
# 7                  4.0                 9.0
# 8                 13.0                16.0
# 9                 14.0                 NaN
# 10                 2.0                15.0
# 11                 NaN                 NaN
# 12                 8.0                14.0
# 13                 8.0                 NaN
# 14                15.0                16.0

# %%
df = pd.read_csv("/content/drive/MyDrive/Black_friday_sales1.csv", index_col = 0, header = 0)

# %%
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 NaN
# 1000009                 5.0                 NaN
# 1000010                14.0                 NaN
# 1000010                 9.0                 NaN
# 1000011                 5.0                12.0

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %% [markdown]
# **Create a DataFrame**

# %%
classes = pd.Series(["Mathematics","Chemistry","Physics","History","Geography","German"])

grades  = pd.Series([90,54,77,22,25])

df1 = pd.DataFrame({"Subjects" : classes, "grades": grades})

# %%
df1.head(6)
# Out:
#       Subjects  grades
# 0  Mathematics    90.0
# 1    Chemistry    54.0
# 2      Physics    77.0
# 3      History    22.0
# 4    Geography    25.0
# 5       German     NaN

# %% [markdown]
# **Version**

# %%
pd.__version__
# Out:
# '1.3.5'

# %% [markdown]
# **Series**

# %%
l = [12,9,8]

s1 = pd.Series(l)

print(s1)
# Out:
# 0    12
# 1     9
# 2     8
# dtype: int64

# %%
l = [12,9,8]

s1 = pd.Series(l, index = ["a","b","c"])

print(s1)
# Out:
# a    12
# b     9
# c     8
# dtype: int64

# %%
d = {"a": 12, "b": 23, "c": 10}

s1 = pd.Series(d)
print(s1)
# Out:
# a    12
# b    23
# c    10
# dtype: int64

# %% [markdown]
# **Homework 1**

# %%
#f1.into()
#f1.tail()

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# **Bad data could be:**
#
# Empty cells
#
# Data in wrong format
#
# Wrong data
#
# Duplicates

# %%
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 NaN
# 1000009                 5.0                 NaN
# 1000010                14.0                 NaN
# 1000010                 9.0                 NaN
# 1000011                 5.0                12.0

# %% [markdown]
# Empty cells

# %%
new_df = df.dropna()

# %%
new_df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000011  P00053842      F  26-35           1             C
# 1000013  P00350442      M  46-50           1             C
# 1000013  P00155442      M  46-50           1             C
# 1000013   P0094542      M  46-50           1             C
# 1000015  P00161842      M  26-35           7             A
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000011                          1               0                   4
# 1000013                          3               1                   2
# 1000013                          3               1                   1
# 1000013                          3               1                   2
# 1000015                          1               0                  10
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000011                 5.0                12.0
# 1000013                 3.0                15.0
# 1000013                11.0                15.0
# 1000013                 4.0                 9.0
# 1000015                13.0                16.0

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
new_df.describe()
# Out:
#          Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  71037.000000    71037.000000        71037.000000        71037.000000
# mean       8.219801        0.402002            2.725185            6.882287
# std        6.482756        0.490306            2.564070            4.510544
# min        0.000000        0.000000            1.000000            2.000000
# 25%        3.000000        0.000000            1.000000            2.000000
# 50%        7.000000        0.000000            1.000000            6.000000
# 75%       14.000000        1.000000            4.000000           10.000000
# max       20.000000        1.000000           15.000000           16.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
new_df = df.fillna(0)

# %%
new_df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 0.0
# 1000009                 5.0                 0.0
# 1000010                14.0                 0.0
# 1000010                 9.0                 0.0
# 1000011                 5.0                12.0

# %%
new_df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       233599.000000
# mean        8.085407        0.410070            5.276542            6.799237
# std         6.521146        0.491847            3.736380            6.217668
# min         0.000000        0.000000            1.000000            0.000000
# 25%         2.000000        0.000000            1.000000            0.000000
# 50%         7.000000        0.000000            5.000000            5.000000
# 75%        14.000000        1.000000            8.000000           14.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count       233599.000000
# mean             3.852756
# std              6.256634
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              8.000000
# max             18.000000

# %%
mean = df["Product_Category_3"].mean()

# %%
mean
# Out:
# 12.669453946534905

# %%
new_df = df.fillna(mean)

# %%
new_df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0           12.669454
# 1000009                 5.0           12.669454
# 1000010                14.0           12.669454
# 1000010                 9.0           12.669454
# 1000011                 5.0           12.000000

# %%
median = df["Product_Category_3"].median()

# %%
median
# Out:
# 14.0

# %%
new_df = df.fillna(median)

# %%
new_df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                14.0
# 1000009                 5.0                14.0
# 1000010                14.0                14.0
# 1000010                 9.0                14.0
# 1000011                 5.0                12.0

# %% [markdown]
# **Homework2**

# %% [markdown]
# Wrong data

# %%
df = pd.read_csv("/content/drive/MyDrive/Black_friday_sales1.csv", header = 0)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0

# %%
import numpy as np

# %%
df["Product_Category_3"].replace(np.nan, 0, inplace = True)
df["Product_Category_2"].replace(np.nan, 0, inplace = True)
df["Product_Category_1"].replace(np.nan, 0, inplace = True)

# %%
df["Stay_In_Current_City_Years"].replace('4+', '4', inplace = True)

# %%
df["Age"].unique()
# Out:
# array(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'],
#       dtype=object)

# %%
df["Age"].replace(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'], ['50','35','45','25','55','60','17'], inplace = True)

# %% [markdown]
# Data in wrong format

# %%
df.head()
# Out:
#    User_ID Product_ID Gender Age  Occupation City_Category  \
# 0  1000004  P00128942      M  50           7             B
# 1  1000009  P00113442      M  35          17             C
# 2  1000010  P00288442      F  45           1             B
# 3  1000010  P00145342      F  45           1             B
# 4  1000011  P00053842      F  35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                          4               1                   5
# 3                          4               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 0.0
# 1                 5.0                 0.0
# 2                14.0                 0.0
# 3                 9.0                 0.0
# 4                 5.0                12.0

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       233599.000000       233599.000000
# mean             6.799237            3.852756
# std              6.217668            6.256634
# min              0.000000            0.000000
# 25%              0.000000            0.000000
# 50%              5.000000            0.000000
# 75%             14.000000            8.000000
# max             18.000000           18.000000

# %%
print(df.dtypes)
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
df["Age"] = df["Age"].astype('int')

# %% [markdown]
# **Homework**

# %% [markdown]
# Duplicates

# %%
df.head()
# Out:
#    User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0  1000004  P00128942      M   50           7             B
# 1  1000009  P00113442      M   35          17             C
# 2  1000010  P00288442      F   45           1             B
# 3  1000010  P00145342      F   45           1             B
# 4  1000011  P00053842      F   35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                          4               1                   5
# 3                          4               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 0.0
# 1                 5.0                 0.0
# 2                14.0                 0.0
# 3                 9.0                 0.0
# 4                 5.0                12.0

# %%
df.drop_duplicates()
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0       1000004  P00128942      M   50           7             B
# 1       1000009  P00113442      M   35          17             C
# 2       1000010  P00288442      F   45           1             B
# 3       1000010  P00145342      F   45           1             B
# 4       1000011  P00053842      F   35           1             C
# ...         ...        ...    ...  ...         ...           ...
# 233594  1006036  P00118942      F   35          15             B
# 233595  1006036  P00254642      F   35          15             B
# 233596  1006036  P00031842      F   35          15             B
# 233597  1006037  P00124742      F   50           1             C
# 233598  1006039  P00316642      F   50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                               4               1                   5
# 3                               4               1                   4
# 4                               1               0                   4
# ...                           ...             ...                 ...
# 233594                          4               1                   8
# 233595                          4               1                   5
# 233596                          4               1                   1
# 233597                          4               0                  10
# 233598                          4               1                   4
#
#         Product_Category_2  Product_Category_3
# 0                     11.0                 0.0
# 1                      5.0                 0.0
# 2                     14.0                 0.0
# 3                      9.0                 0.0
# 4                      5.0                12.0
# ...                    ...                 ...
# 233594                 0.0                 0.0
# 233595                 8.0                 0.0
# 233596                 5.0                12.0
# 233597                16.0                 0.0
# 233598                 5.0                 0.0
#
# [233599 rows x 11 columns]

# %%
#df.drop_duplicates(subset=["Gender"], keep='first', inplace=True, ignore_index= True)

# %%
df
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0       1000004  P00128942      M   50           7             B
# 1       1000009  P00113442      M   35          17             C
# 2       1000010  P00288442      F   45           1             B
# 3       1000010  P00145342      F   45           1             B
# 4       1000011  P00053842      F   35           1             C
# ...         ...        ...    ...  ...         ...           ...
# 233594  1006036  P00118942      F   35          15             B
# 233595  1006036  P00254642      F   35          15             B
# 233596  1006036  P00031842      F   35          15             B
# 233597  1006037  P00124742      F   50           1             C
# 233598  1006039  P00316642      F   50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                               4               1                   5
# 3                               4               1                   4
# 4                               1               0                   4
# ...                           ...             ...                 ...
# 233594                          4               1                   8
# 233595                          4               1                   5
# 233596                          4               1                   1
# 233597                          4               0                  10
# 233598                          4               1                   4
#
#         Product_Category_2  Product_Category_3
# 0                     11.0                 0.0
# 1                      5.0                 0.0
# 2                     14.0                 0.0
# 3                      9.0                 0.0
# 4                      5.0                12.0
# ...                    ...                 ...
# 233594                 0.0                 0.0
# 233595                 8.0                 0.0
# 233596                 5.0                12.0
# 233597                16.0                 0.0
# 233598                 5.0                 0.0
#
# [233599 rows x 11 columns]

# %% [markdown]
# **Correlations**

# %%
df.corr()
# Out:
#                      User_ID       Age  Occupation  Marital_Status  \
# User_ID             1.000000  0.040095   -0.023988        0.019883
# Age                 0.040095  1.000000    0.095893        0.305679
# Occupation         -0.023988  0.095893    1.000000        0.021872
# Marital_Status      0.019883  0.305679    0.021872        1.000000
# Product_Category_1  0.006428  0.058256   -0.010465        0.018860
# Product_Category_2  0.003590  0.025351    0.009089        0.008597
# Product_Category_3 -0.000533 -0.007014    0.013456       -0.006879
#
#                     Product_Category_1  Product_Category_2  Product_Category_3
# User_ID                       0.006428            0.003590           -0.000533
# Age                           0.058256            0.025351           -0.007014
# Occupation                   -0.010465            0.009089            0.013456
# Marital_Status                0.018860            0.008597           -0.006879
# Product_Category_1            1.000000           -0.035237           -0.389516
# Product_Category_2           -0.035237            1.000000            0.087280
# Product_Category_3           -0.389516            0.087280            1.000000

# %% [markdown]
# ### **Seaborn**

# %%
import seaborn as sns

# %%
sns.distplot(df['Product_Category_1'][:50])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(df['Product_Category_1'][:50])

# %%
sns.distplot([0, 1, 2, 3, 4, 5])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot([0, 1, 2, 3, 4, 5,6], kde = True, bins = 14)

# %%
sns.displot([0, 1, 2, 3, 4, 5],kde = True, kde_kws={'clip': (0.0, 6.0)}, bins = 4, x=None, y=None, hue=None, row=None, col=None, weights=None, kind='hist', rug=False, rug_kws=None, log_scale=None, legend=True, palette=None, hue_order=None, hue_norm=None, color=None, col_wrap=None, row_order=None, col_order=None, height=5, aspect=1, facet_kws=None)

# %%
df.head(10)
# Out:
#    User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0  1000004  P00128942      M   50           7             B
# 1  1000009  P00113442      M   35          17             C
# 2  1000010  P00288442      F   45           1             B
# 3  1000010  P00145342      F   45           1             B
# 4  1000011  P00053842      F   35           1             C
# 5  1000013  P00350442      M   50           1             C
# 6  1000013  P00155442      M   50           1             C
# 7  1000013   P0094542      M   50           1             C
# 8  1000015  P00161842      M   35           7             A
# 9  1000022  P00067942      M   25          15             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                          4               1                   5
# 3                          4               1                   4
# 4                          1               0                   4
# 5                          3               1                   2
# 6                          3               1                   1
# 7                          3               1                   2
# 8                          1               0                  10
# 9                          4               0                   5
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 0.0
# 1                 5.0                 0.0
# 2                14.0                 0.0
# 3                 9.0                 0.0
# 4                 5.0                12.0
# 5                 3.0                15.0
# 6                11.0                15.0
# 7                 4.0                 9.0
# 8                13.0                16.0
# 9                14.0                 0.0

# %%
gf = df.groupby('User_ID')

# %%
gf_new = gf.sum()

# %%
gf_new.sort('Product_Category_2').head(10)

# %%
gf_new.sort_values(['Product_Category_1','Product_Category_2'],ascending=False).head(10)
# Out:
#            Age  Occupation  Marital_Status  Product_Category_1  \
# User_ID
# 1001680  15470        8840             442                2607
# 1004277  18225        6480               0                2536
# 1000889  19050        7620               0                2484
# 1001941  17460        6596               0                2452
# 1001181  16560        2576             368                2288
# 1004344  11830         338               0                2146
# 1001150  10955        6260               0                1933
# 1001015  13455         897             299                1915
# 1001285  13680        1216             304                1903
# 1003618  18720        5304             312                1892
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1001680              2671.0              1211.0
# 1004277              2727.0              1166.0
# 1000889              2778.0              1060.0
# 1001941              2359.0              1128.0
# 1001181              2135.0              1060.0
# 1004344              1993.0               954.0
# 1001150              1754.0               796.0
# 1001015              1853.0               829.0
# 1001285              1806.0               760.0
# 1003618              2340.0               931.0

# %%
# Jointplot compares 2 distributions and plots a scatter plot by default
# As we can see as people tend to speed they also tend to drink & drive
# With kind you can create a regression line with kind='reg'
# You can create a 2D KDE with kind='kde'
# Kernal Density Estimation estimates the distribution of data
# You can create a hexagon distribution with kind='hex'
sns.jointplot(x=df['Occupation'], y=df['Age'], data=df, kind='reg')

# %%
import matplotlib.pyplot as plt
