# %% [markdown]
# Different ways of creating a DataFrame:
# 1. Using CSV
# 2. Using Excel
# 3. Using Python Dictionary
# 4. Using list of tuples
# 5. Using list of dictionaries

# %%
import pandas as pd

# %%
csv = pd.read_csv('data.csv')
csv
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
xlsx1 = pd.read_excel('Test.xlsx','Sheet1')
xlsx1
# Out:
#    No. Name Address
# 0    1    a    asd1
# 1    2    b    sdf2
# 2    3    c  kbjas3
# 3    4    d    asd1
# 4    5    e    sdf2
# 5    6    f  kbjas3

# %%
dic = {
    'Date' : ['2002/08/12' , '2002/08/12' ],
    'Name' : ['Taaha' ,'Hussain' ]
}
dicDF = pd.DataFrame(dic)
dicDF
# Out:
#          Date     Name
# 0  2002/08/12    Taaha
# 1  2002/08/12  Hussain

# %%
my = pd.read_csv('mine.csv')
my
# Out:
#        Name   Age  Roll No
# 0    Taaha   12.0     21.0
# 1  Hussain    NaN      NaN
# 2      Khan  14.0     44.0

# %%
meaan = my['Age'].mean(axis=0)
my.fillna(meaan)
# Out:
#        Name   Age  Roll No
# 0    Taaha   12.0     21.0
# 1  Hussain   13.0     13.0
# 2      Khan  14.0     44.0

# %%
my.fillna(method='ffill')  #forward fill
#copies value verticaly
# Out:
#        Name   Age  Roll No
# 0    Taaha   12.0     21.0
# 1  Hussain   12.0     21.0
# 2      Khan  14.0     44.0

# %%
my.fillna(method='ffill' ,axis='columns')  #forward fill
#copies value horizontaly
# Out:
#        Name       Age   Roll No
# 0    Taaha       12.0      21.0
# 1  Hussain   Hussain   Hussain
# 2      Khan      14.0      44.0

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Program Files\KMSpico\temp\ipykernel_18424\571562942.py in <module>
#       1 import numpy as np
# ----> 2 na = np.naan
#       3 na
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\numpy\__init__.py in __getattr__(attr)
#     312
#     313             raise AttributeError("module {!r} has no attribute "
# --> 314                                  "{!r}".format(__name__, attr))
#     315
#     316         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'naan'
